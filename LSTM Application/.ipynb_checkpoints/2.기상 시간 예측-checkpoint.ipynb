# %% [markdown]
# # **2. 기상시간 예측하기**

# %% [markdown]
# ** 일 단위의 사용자 기상 시간 데이터를 이용하여 다음 기상 시간을 예측한다**

# %%
## 라이브러리 import

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
## 데이터 불러오기

df_orig = pd.read_csv('./nodate.csv', error_bad_lines=False) 
df = df_orig[['wake_time','sleep_second']]
df.head()
# Out:
#   wake_time  sleep_second
# 0      7:10         25800
# 1      7:00         25200
# 2      7:00         25200
# 3      5:40         20400
# 4      7:30         27000

# %% [markdown]
# ---------------
#
# ## **데이터 확인 및 전처리**

# %%
## 시각화 -> 시계열 형태 확인

df['sleep_second'].plot()

# %%
# 0~55(56일): 학습, 56~69(14일): 검증, 70~83(14일): 테스트

train = df.loc[:56, ['sleep_second']]
val = df.loc[56:70, ['sleep_second']]
test = df.loc[70:, ['sleep_second']]

# %%
## 다시 시각화

ax = train.plot()
val.plot(ax=ax)
test.plot(ax=ax)
plt.legend(['train','val', 'test'])

# %%
## 0~1 사이 값으로 스케일링 하기
## MinMaxScaler 사용 -> 참고: https://datascienceschool.net/view-notebook/f43be7d6515b48c0beb909826993c856/

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_train = scaler.fit_transform(train)
scaled_val = scaler.transform(val)
scaled_test = scaler.transform(test) # train 스케일 할 때 fit 해준 분포 그대로 가져와야 하기 때문에 transform만 해주기

# %%
## df로 바꾸기
train = pd.DataFrame(scaled_train, columns=['sleep_second'], index=train.index)
val = pd.DataFrame(scaled_val, columns=['sleep_second'], index=val.index)
test= pd.DataFrame(scaled_test, columns=['sleep_second'], index=test.index)

# %%
## window(LSTM 훈련 단위)를 7(일주일)로 설정하고 shift()로 window 크기만큼 데이터만 이동 시키기

for s in range(1, 8):
    train['shift_{}'.format(s)] = train['sleep_second'].shift(s)
    val['shift_{}'.format(s)] = val['sleep_second'].shift(s)
    test['shift_{}'.format(s)] = test['sleep_second'].shift(s)

test.head(8)
# Out:
#     sleep_second  shift_1  shift_2  shift_3  shift_4  shift_5  shift_6  \
# 70         0.225      NaN      NaN      NaN      NaN      NaN      NaN
# 71         0.300    0.225      NaN      NaN      NaN      NaN      NaN
# 72         0.250    0.300    0.225      NaN      NaN      NaN      NaN
# 73         0.075    0.250    0.300    0.225      NaN      NaN      NaN
# 74         0.250    0.075    0.250    0.300    0.225      NaN      NaN
# 75         0.550    0.250    0.075    0.250    0.300    0.225      NaN
# 76         1.000    0.550    0.250    0.075    0.250    0.300    0.225
# 77         0.175    1.000    0.550    0.250    0.075    0.250    0.300
#
#     shift_7
# 70      NaN
# 71      NaN
# 72      NaN
# 73      NaN
# 74      NaN
# 75      NaN
# 76      NaN
# 77    0.225

# %%
## null값 제거 + X/y 나누기

X_train = train.dropna().drop('sleep_second', axis=1)
y_train = train.dropna()[['sleep_second']]
X_val = val.dropna().drop('sleep_second', axis=1)
y_val = val.dropna()[['sleep_second']]
X_test = test.dropna().drop('sleep_second', axis=1)
y_test = test.dropna()[['sleep_second']]

# %%
X_val.head()
# Out:
#     shift_1  shift_2  shift_3  shift_4  shift_5  shift_6  shift_7
# 63    0.775    1.000    0.325    0.075    0.275    0.275    0.250
# 64    0.250    0.775    1.000    0.325    0.075    0.275    0.275
# 65    0.275    0.250    0.775    1.000    0.325    0.075    0.275
# 66    0.225    0.275    0.250    0.775    1.000    0.325    0.075
# 67    0.100    0.225    0.275    0.250    0.775    1.000    0.325

# %%
## 분석할 때 numpy ndarray 써야되니까 values로 바꾸기

X_train = X_train.values
X_val = X_val.values
X_test = X_test.values

y_train = y_train.values
y_val = y_val.values
y_test = y_test.values

# %%
## Keras LSTM 이용하려면 3차원 변환 필요 -> (데이터 수, slot 수, feature 수)

## (데이터 수, slot 수) 확인 먼저 해보기
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (50, 7)
# (50, 1)
# (8, 7)
# (8, 1)

# %%
## reshape 하기 
X_train_t = X_train.reshape(X_train.shape[0], 7, 1)
X_val_t = X_val.reshape(X_val.shape[0], 7, 1)
X_test_t = X_test.reshape(X_test.shape[0], 7, 1)



print(X_train_t.shape)
print(X_test_t.shape)
# Out:
# (50, 7, 1)
# (7, 7, 1)

# %% [markdown]
# --------------
#
# ## **학습 수행**

# %%
## LSTM 모델 만들기 -> Keras 사용

import keras
from keras.layers import LSTM 
from keras.models import Sequential # 레이어를 선형으로 쌓는 모델
from keras.layers import Dense # 완전 연결 레이어
import keras.backend as K 
from keras.callbacks import EarlyStopping

K.clear_session()
    
model = Sequential() # Sequeatial Model 객체 
model.add(LSTM(40, input_shape=(7, 1)))# (slot 수, feature 수) 
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy']) 
model.summary() # 모델 내용 확인


#optimizer: adam, sgd, RMSprop, Adagrad
#activation: sigmoid, relu , softmax
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 40)                6720
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 6,761
# Trainable params: 6,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
## fit

early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1) 

model.fit(X_train_t, y_train, epochs=100,
          batch_size=30, verbose=1, callbacks=[early_stop], validation_data=(X_val_t, y_val))
# Out:
# Train on 50 samples, validate on 8 samples
# Epoch 1/100
# 50/50 [==============================] - 1s 10ms/step - loss: 0.0889 - accuracy: 0.0200 - val_loss: 0.0770 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0870 - accuracy: 0.0200 - val_loss: 0.0748 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 50/50 [==============================] - 0s 339us/step - loss: 0.0855 - accuracy: 0.0200 - val_loss: 0.0729 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0841 - accuracy: 0.0200 - val_loss: 0.0711 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0823 - accuracy: 0.0200 - val_loss: 0.0696 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0814 - accuracy: 0.0200 - val_loss: 0.0682 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0806 - accuracy: 0.0200 - val_loss: 0.0670 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0796 - accuracy: 0.0200 - val_loss: 0.0659 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0786 - accuracy: 0.0200 - val_loss: 0.0650 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0783 - accuracy: 0.0200 - val_loss: 0.0642 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0775 - accuracy: 0.0200 - val_loss: 0.0635 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0771 - accuracy: 0.0200 - val_loss: 0.0629 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0767 - accuracy: 0.0200 - val_loss: 0.0623 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0763 - accuracy: 0.0200 - val_loss: 0.0618 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0761 - accuracy: 0.0200 - val_loss: 0.0614 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0758 - accuracy: 0.0200 - val_loss: 0.0610 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0754 - accuracy: 0.0200 - val_loss: 0.0605 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0751 - accuracy: 0.0200 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0747 - accuracy: 0.0200 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0742 - accuracy: 0.0200 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0737 - accuracy: 0.0200 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0732 - accuracy: 0.0200 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0726 - accuracy: 0.0200 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0721 - accuracy: 0.0200 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0716 - accuracy: 0.0200 - val_loss: 0.0564 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0710 - accuracy: 0.0200 - val_loss: 0.0557 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0705 - accuracy: 0.0200 - val_loss: 0.0551 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0698 - accuracy: 0.0200 - val_loss: 0.0543 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0692 - accuracy: 0.0200 - val_loss: 0.0536 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0685 - accuracy: 0.0200 - val_loss: 0.0528 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0678 - accuracy: 0.0200 - val_loss: 0.0519 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0671 - accuracy: 0.0200 - val_loss: 0.0511 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0663 - accuracy: 0.0200 - val_loss: 0.0502 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0656 - accuracy: 0.0200 - val_loss: 0.0494 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0648 - accuracy: 0.0200 - val_loss: 0.0485 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0639 - accuracy: 0.0200 - val_loss: 0.0475 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0630 - accuracy: 0.0200 - val_loss: 0.0465 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0624 - accuracy: 0.0200 - val_loss: 0.0456 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0611 - accuracy: 0.0200 - val_loss: 0.0446 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0602 - accuracy: 0.0200 - val_loss: 0.0435 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0591 - accuracy: 0.0200 - val_loss: 0.0425 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0581 - accuracy: 0.0200 - val_loss: 0.0414 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0571 - accuracy: 0.0200 - val_loss: 0.0402 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0558 - accuracy: 0.0200 - val_loss: 0.0391 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0547 - accuracy: 0.0200 - val_loss: 0.0380 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0535 - accuracy: 0.0200 - val_loss: 0.0369 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0523 - accuracy: 0.0200 - val_loss: 0.0357 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0511 - accuracy: 0.0200 - val_loss: 0.0346 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0499 - accuracy: 0.0200 - val_loss: 0.0333 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0485 - accuracy: 0.0200 - val_loss: 0.0322 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0470 - accuracy: 0.0400 - val_loss: 0.0311 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0458 - accuracy: 0.0400 - val_loss: 0.0301 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0447 - accuracy: 0.0400 - val_loss: 0.0290 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0437 - accuracy: 0.0600 - val_loss: 0.0281 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0422 - accuracy: 0.0600 - val_loss: 0.0272 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0410 - accuracy: 0.0800 - val_loss: 0.0265 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0400 - accuracy: 0.0800 - val_loss: 0.0258 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0390 - accuracy: 0.0800 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0380 - accuracy: 0.0800 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0368 - accuracy: 0.0800 - val_loss: 0.0230 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0359 - accuracy: 0.0800 - val_loss: 0.0222 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0350 - accuracy: 0.0800 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0343 - accuracy: 0.0800 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0333 - accuracy: 0.0800 - val_loss: 0.0200 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0325 - accuracy: 0.0800 - val_loss: 0.0194 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0321 - accuracy: 0.0800 - val_loss: 0.0192 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0309 - accuracy: 0.0800 - val_loss: 0.0185 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0302 - accuracy: 0.0800 - val_loss: 0.0177 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0295 - accuracy: 0.0800 - val_loss: 0.0170 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0286 - accuracy: 0.0800 - val_loss: 0.0165 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0279 - accuracy: 0.0800 - val_loss: 0.0159 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0273 - accuracy: 0.0800 - val_loss: 0.0154 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0266 - accuracy: 0.0800 - val_loss: 0.0150 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0259 - accuracy: 0.0800 - val_loss: 0.0144 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0254 - accuracy: 0.0800 - val_loss: 0.0137 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0246 - accuracy: 0.0800 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0239 - accuracy: 0.0800 - val_loss: 0.0124 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0234 - accuracy: 0.0800 - val_loss: 0.0118 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0227 - accuracy: 0.0800 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0221 - accuracy: 0.0800 - val_loss: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0216 - accuracy: 0.0800 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 50/50 [==============================] - 0s 299us/step - loss: 0.0211 - accuracy: 0.0800 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 50/50 [==============================] - 0s 319us/step - loss: 0.0207 - accuracy: 0.0800 - val_loss: 0.0100 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 50/50 [==============================] - 0s 259us/step - loss: 0.0203 - accuracy: 0.0800 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 50/50 [==============================] - 0s 279us/step - loss: 0.0204 - accuracy: 0.0800 - val_loss: 0.0088 - val_accuracy: 0.0000e+00
# Epoch 00085: early stopping

# %% [markdown]
# ----------------
#
# ## **예측 수행 및 평가**

# %%
## 테스트 데이터로 예측

y_pred = model.predict(X_test_t, batch_size=30)

y_pred
# Out:
# array([[0.40813646],
#        [0.24678332],
#        [0.13925537],
#        [0.16689554],
#        [0.34565002],
#        [0.7067962 ],
#        [0.7570445 ]], dtype=float32)

# %%
plt.figure(figsize=(15,5))

plt.plot(y_test, color='red', label='true')
plt.plot(y_pred, color='blue', label='pred')

# %%
eval_ = model.evaluate(X_test_t, y_test, batch_size=30)
eval_
# Out:
# 7/7 [==============================] - 0s 285us/step
# [0.0171518512070179, 0.0]
